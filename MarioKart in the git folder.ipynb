# %%
# %pip install datasets

# %%
# %restart_python

# %%
# %cd /Workspace/Users/kristofer.schlachter@epicgames.com/wm_mariokart64/diamond
# %pip install -r requirements.txt

# %%
# %restart_python

# %%
# !git clone https://huggingface.co/datasets/DereWah/mk64-steering/ /Volumes/personal_schema/kschlachter/v_kschlachter/diamond/mk64-steering

# %%
#!git clone https://huggingface.co/datasets/DereWah/mk64-steering/ /local_disk0/mk64-steering2

# %%
#%pip install --upgrade datasets huggingface_hub

# %%
'''
from datasets import load_dataset
import os
vol_cache = "/Volumes/insights_ml_iandev/fn_discovery_reco_sandbox/artifacts/serve_hf_model"
local_cache = "local_disk0/serve_hf_model"

if not os.path.exists(vol_cache): os.makedirs(vol_cache)
os.environ["HF_DATASETS_CACHE"] = vol_cache
ds = load_dataset("DereWah/mk64_steering")
:%shell
# %sh
echo $LD_LIBRARY_PATH
ls /usr/lib/x86_64-linux-gnu/ | grep libcudart
'''

# %%
# !rm -rf /local_disk0/diamond/processed

# %%
# !python diamond/src/process_dataset_tar.py /Volumes/personal_schema/kschlachter/v_kschlachter/diamond/mk64-steering/LR/ //Volumes/personal_schema/kschlachter/v_kschlachter/diamond/processed

# %%
#!python diamond/src/process_dataset_tar.py /local_disk0/mk64-steering2/LR/ /local_disk0/diamond/processed

# %%
# %pip install  torch==2.4.0+cu118 torchvision==0.19.0+cu118 torchaudio==2.4.0+cu118 \
  --index-url https://download.pytorch.org/whl/cu118

# %%
# %restart_python

# %%
# !ls /local_disk0/diamond/processed/low_res/train/

# %%
#!rm -rf /local_disk0/diamond/checkpoints/

# %% [markdown]
# Make sure tensorboard is killed before training.

# %%
#!cd diamond;  HYDRA_FULL_ERROR=1  python src/main.py --config-name=trainer_no_upsampling
# !cd diamond;  HYDRA_FULL_ERROR=1  python src/main.py

# %%
# %debug
